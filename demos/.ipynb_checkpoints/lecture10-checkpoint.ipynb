# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from scipy.stats import norm
var = norm()

n_samples = 100

tmp = np.arange(-3,3,0.25)
print(tmp)
cdf = [var.cdf(j) for j in tmp]
plt.plot(tmp,cdf)
plt.show()

xs = []
us = []

for i in range(n_samples):
    u = np.random.rand()
    x = var.ppf(u)
    us.append(u)
    xs.append(x)
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(tmp,cdf)
    plt.scatter(-3.5*np.ones(len(us)),us,color='r')
    plt.scatter(xs,us,marker='x')
    plt.scatter(xs,np.zeros(len(xs)))
    plt.plot([-3.5,x,x],[u,u,0],':k')
    plt.xlim([-4,4])
    plt.subplot(1,2,2)
    plt.hist(xs)
    plt.xlim([-4,4])
#     plt.hold(True)
    plt.show()
# Out:
# [-3.   -2.75 -2.5  -2.25 -2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25
#   0.    0.25  0.5   0.75  1.    1.25  1.5   1.75  2.    2.25  2.5   2.75]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-59a2f5b0a67b> in <module>()
#      19     xs.append(x)
#      20     plt.figure(figsize=(12,4))
# ---> 21     plt.subplot(2,1,1)
#      22     plt.plot(tmp,cdf)
#      23     plt.scatter(-3.5*np.ones(len(us)),us,color='r')
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1020
#    1021     fig = gcf()
# -> 1022     a = fig.add_subplot(*args, **kwargs)
#    1023     bbox = a.bbox
#    1024     byebye = []
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     506
#     507         # this call may differ for non-sep axes, e.g., polar
# --> 508         self._init_axis()
#     509
#     510         if axisbg is None:
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     564     def _init_axis(self):
#     565         "move this out of __init__ because non-separable axes don't use it"
# --> 566         self.xaxis = maxis.XAxis(self)
#     567         self.spines['bottom'].register_axis(self.xaxis)
#     568         self.spines['top'].register_axis(self.xaxis)
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, pickradius)
#     656         self._minor_tick_kw = dict()
#     657
# --> 658         self.cla()
#     659         self._set_scale('linear')
#     660
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     755
#     756         self.majorTicks.extend([self._get_tick(major=True)])
# --> 757         self.minorTicks.extend([self._get_tick(major=False)])
#     758         self._lastNumMajorTicks = 1
#     759         self._lastNumMinorTicks = 1
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1673         else:
#    1674             tick_kw = self._minor_tick_kw
# -> 1675         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1676
#    1677     def _get_label(self):
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     398                           linestyle='None', marker=self._tickmarkers[0],
#     399                           markersize=self._size,
# --> 400                           markeredgewidth=self._width, zorder=self._zorder)
#     401         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     402         self._set_artist_props(l)
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     337         self.set_color(color)
#     338         self._marker = MarkerStyle()
# --> 339         self.set_marker(marker)
#     340
#     341         self._markevery = None
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/lines.py in set_marker(self, marker)
#    1069
#    1070         """
# -> 1071         self._marker.set_marker(marker)
#    1072         self.stale = True
#    1073
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     253
#     254         self._marker = marker
# --> 255         self._recache()
#     256
#     257     def get_path(self):
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/markers.py in _recache(self)
#     191         self._capstyle = 'butt'
#     192         self._filled = True
# --> 193         self._marker_function()
#     194
#     195     if six.PY3:
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/markers.py in _set_tickup(self)
#     697
#     698     def _set_tickup(self):
# --> 699         self._transform = Affine2D().scale(1.0, 1.0)
#     700         self._snap_threshold = 1.0
#     701         self._filled = False
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, matrix, **kwargs)
#    1794         If *matrix* is None, initialize with the identity transform.
#    1795         """
# -> 1796         Affine2DBase.__init__(self, **kwargs)
#    1797         if matrix is None:
#    1798             matrix = np.identity(3)
#
# /Users/adams/anaconda/lib/python3.5/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1638     is_affine = True
#    1639
# -> 1640     def __init__(self, *args, **kwargs):
#    1641         Transform.__init__(self, *args, **kwargs)
#    1642         self._inverted = None
#
# KeyboardInterrupt:

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
x = np.random.randn(1000)

# Univariate histogram
sns.distplot(x)

# %%
x = np.random.randn(200)
y = np.random.randn(200)*2.0

# Bivariate histogram
sns.jointplot(x,y,xlim=[-10,10],ylim=[-10,10])

# %% [markdown]
# # Sources of Randomness

# %%
# Running this code multiple times
# will produce the same numbers unless
# the seed is changed

np.random.seed(1)
print(np.random.randint(0,100,10))

# %% [markdown]
# # Inverse CDF Sampling
